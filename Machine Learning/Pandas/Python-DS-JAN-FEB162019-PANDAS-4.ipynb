# %% [markdown]
# DATA INPUT AND OUTPUT USING PANDAS
# CSV
# EXCEL
# HTML
# SQL
#
# When you install Jupyter via anaconda distribution, all the below packages come in by defauly
#
# When installing Jupyter outside anaconda distribution, you will need to use the following install commands
# Libraries that need to be installed with pip or conda
# conda install sqlalchemy
# conda install lxml
# conda install html5lib
# conda install BeautifulSoup4
#
# to read any file, type read_ and click tab

# %%
import pandas as pd

# %%
import numpy as np

# %%
### make sure that the csv files are in the same location of your jupyter notebook
pd.read_csv('example.csv')
# Out:
#         a       b       c       d
# 0       0       1       2       3
# 1       4       5       6       7
# 2       8       9      10      11
# 3      12      13      14      15
# 4    1000    2000    3000    4000
# 5  "1000"  "2000"  "#000"  "4000"

# %%
### reading a csv file and saving to dataframe
df = pd.read_csv('example.csv')
print(df)
# Out:
#       a     b     c     d
# 0     0     1     2     3
# 1     4     5     6     7
# 2     8     9    10    11
# 3    12    13    14    15
# 4  1000  2000  3000  4000

# %%
### what if the file is in a different folder - as in real life scenario
df100 = pd.read_csv('C:\\Users\\anand\\Python-DataScience-Anand\\Simplilearn\\SL-JAN12-FEB16-2019\\Pandas\\example.csv')
df100
# Out:
#         a       b       c       d
# 0       0       1       2       3
# 1       4       5       6       7
# 2       8       9      10      11
# 3      12      13      14      15
# 4    1000    2000    3000    4000
# 5  "1000"  "2000"  "#000"  "4000"

# %%
# Out:
#       a     b     c     d
# 0     0     1     2     3
# 1     4     5     6     7
# 2     8     9    10    11
# 3    12    13    14    15
# 4  1000  2000  3000  4000

# %%
df1 = pd.read_csv('C:\\Users\\anand\\Python-DataScience-Anand\\Pandas\\example.csv')
df1

### ALWAYS USE DOUBLE BACK WARD SLASHES so that python does not confuse this with escape character like "\n" or "\t" for tab etc
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
### reading excel file with .xls or .xlsx extension
df_weightloss = pd.read_excel('C:\\Users\\anand\\Python-DataScience-Anand\\Pandas\\DietWeightLoss.xls')

# %%
### use tab to understand diffrent files that can be read using read
## pd.read_

# %%
df_weightloss
# Out:
#     WeightLoss Diet
# 0          9.9    A
# 1          9.6    A
# 2          8.0    A
# 3          4.9    A
# 4         10.2    A
# 5          9.0    A
# 6          9.8    A
# 7         10.8    A
# 8          6.2    A
# 9          8.3    A
# 10        12.9    A
# 11        11.8    A
# 12         5.5    A
# 13         9.3    A
# 14        11.5    A
# 15         9.5    B
# 16         3.8    B
# 17        11.5    B
# 18         9.2    B
# 19         4.5    B
# 20         8.9    B
# 21         5.2    B
# 22         8.2    B
# 23         7.5    B
# 24        12.7    B
# 25        10.0    B
# 26        10.0    B
# 27        11.7    B
# 28         8.2    B
# 29        12.7    B
# 30        10.8    C
# 31        10.2    C
# 32        14.4    C
# 33         8.7    C
# 34        12.2    C
# 35        12.9    C
# 36        13.0    C
# 37        15.1    C
# 38        14.5    C
# 39        13.0    C
# 40        12.5    C
# 41        10.8    C
# 42        10.5    C
# 43        12.2    C
# ...

# %% [markdown]
# WRITE INTO A FILE FROM A DATAFRAME

# %%
### writing to an excel file 
## weightloss.to_excel('new_diet_data.xls')

# %%
df_weightloss.to_excel('feb2_weightloss.xls')

# %%
### to check whether the new file got created - read the file
pd.read_excel('feb2_weightloss.xls')
# Out:
#     WeightLoss Diet
# 0          9.9    A
# 1          9.6    A
# 2          8.0    A
# 3          4.9    A
# 4         10.2    A
# 5          9.0    A
# 6          9.8    A
# 7         10.8    A
# 8          6.2    A
# 9          8.3    A
# 10        12.9    A
# 11        11.8    A
# 12         5.5    A
# 13         9.3    A
# 14        11.5    A
# 15         9.5    B
# 16         3.8    B
# 17        11.5    B
# 18         9.2    B
# 19         4.5    B
# 20         8.9    B
# 21         5.2    B
# 22         8.2    B
# 23         7.5    B
# 24        12.7    B
# 25        10.0    B
# 26        10.0    B
# 27        11.7    B
# 28         8.2    B
# 29        12.7    B
# 30        10.8    C
# 31        10.2    C
# 32        14.4    C
# 33         8.7    C
# 34        12.2    C
# 35        12.9    C
# 36        13.0    C
# 37        15.1    C
# 38        14.5    C
# 39        13.0    C
# 40        12.5    C
# 41        10.8    C
# 42        10.5    C
# 43        12.2    C
# ...

# %%
df_weightloss.to_csv('feb2_weightloss.csv')

# %%
newdietdf = pd.read_excel('new_diet_weightloss.xls')

# %%
print(type(newdietdf))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
## to get the top 5 records of your data frame 
newdietdf.head()
# Out:
#    WeightLoss Diet
# 0         9.9    A
# 1         9.6    A
# 2         8.0    A
# 3         4.9    A
# 4        10.2    A

# %%
### to get a specific number of records from data frame
newdietdf.head(20)
# Out:
#     WeightLoss Diet
# 0          9.9    A
# 1          9.6    A
# 2          8.0    A
# 3          4.9    A
# 4         10.2    A
# 5          9.0    A
# 6          9.8    A
# 7         10.8    A
# 8          6.2    A
# 9          8.3    A
# 10        12.9    A
# 11        11.8    A
# 12         5.5    A
# 13         9.3    A
# 14        11.5    A
# 15         9.5    B
# 16         3.8    B
# 17        11.5    B
# 18         9.2    B
# 19         4.5    B

# %%
### to get the bottom 5 records from the dataframe
newdietdf.tail()
# Out:
#     WeightLoss Diet
# 55        11.8    D
# 56         7.1    D
# 57         9.4    D
# 58        13.7    D
# 59        13.7    D

# %%
### to get the specific number of records from the bottom of the file
newdietdf.tail(20)
# Out:
#     WeightLoss Diet
# 40        12.5    C
# 41        10.8    C
# 42        10.5    C
# 43        12.2    C
# 44        10.9    C
# 45        13.2    D
# 46         9.5    D
# 47        10.6    D
# 48         9.9    D
# 49         9.5    D
# 50        10.5    D
# 51        11.8    D
# 52         5.8    D
# 53        10.0    D
# 54        11.6    D
# 55        11.8    D
# 56         7.1    D
# 57         9.4    D
# 58        13.7    D
# 59        13.7    D

# %%
df
# Out:
#       a     b     c     d
# 0     0     1     2     3
# 1     4     5     6     7
# 2     8     9    10    11
# 3    12    13    14    15
# 4  1000  2000  3000  4000

# %%
#### writing into a file from dataframe
##### click tab key after df.to to get all options
### below creates a My_Ouput.csv file
#### reason for index = False is index also gets saved as a column 
df.to_csv('My_Output1',sep=',')

# %%
pd.read_csv('My_Output1')  #### note the column Unnamed which also stores index
# Out:
#    Unnamed: 0     a     b     c     d
# 0           0     0     1     2     3
# 1           1     4     5     6     7
# 2           2     8     9    10    11
# 3           3    12    13    14    15
# 4           4  1000  2000  3000  4000

# %%
pd.read_csv('My_Output1')  #### note the column Unnamed which also stores index
#pd.read_csv('My_Output1')  #### note the column Unnamed which also stores index
# Out:
#         :a:b:c:d
# 0      0:0:1:2:3
# 1      1:4:5:6:7
# 2    2:8:9:10:11
# 3  3:12:13:14:15

# %%
df.to_csv('My_Output2',index=False)

# %%
df
# Out:
#       a     b     c     d
# 0     0     1     2     3
# 1     4     5     6     7
# 2     8     9    10    11
# 3    12    13    14    15
# 4  1000  2000  3000  4000

# %%
pd.read_csv('My_Output2')
# Out:
#       a     b     c     d
# 0     0     1     2     3
# 1     4     5     6     7
# 2     8     9    10    11
# 3    12    13    14    15
# 4  1000  2000  3000  4000

# %% [markdown]
# READING AND WRITING FROM EXCEL FILES
#       PANDAS CAN ONLY IMPORT DATA.
#       DOES NOT IMPORT FORMULAS OR MACROS
#       TRYING TO READ EXCEL FILE WITH FORMULAS MAY CAUSE PANDAS TO CRASH
#       WE MAY BE ASKED TO INSTALL XLRD LIBRARY(IDEALLY INSTALLED AUTOMATICALLY WITH ANACONDA
#       Distribution)
#       IF ERROR
#          conda install xlrd

# %%
#### to read an excel file, pass file name and sheet name. if no sheet name given, sheet1 is assumed
### pandas reads as a dataframe
df=pd.read_excel('myexcel.xlsx',sheet_name='newsheet')
df
# Out:
#     A   B   C   D
# 0   1   2   3   4
# 1   5   5  78   8
# 2  10  11  12  13

# %%
df1=pd.read_excel('myexcel.xlsx',sheet_name='newsheet1')
df1
# Out:
#     E   F    G    H
# 0   2   3    3    4
# 1   4   5   78   99
# 2  10  11  100  199

# %%
df2=pd.read_excel('myexcel.xlsx',sheet_name='newsheet2')
df2
# Out:
#       I     J    K    L
# 0  1000   999  999    4
# 1     4   500  989   99
# 2    10  1872  100  199

# %%
df5=pd.read_excel('myexcel.xlsx')

# %%
print(df5)
# Out:
#     A   B   C   D
# 0   1   2   3   4
# 1   5   5  78   8
# 2  10  11  12  13

# %%
#### write to excel
df5.to_excel('myoutputxl.xlsx',sheet_name='NewSheetOut2')
## over writes the existing sheet

# %%
### example for writing into a new shete and append to existing

# %%
dfout1=pd.read_excel('myoutputxl.xlsx',sheet_name='NewSheetOut2')

# %%
dfout1
# Out:
#     A   B   C   D
# 0   1   2   3   4
# 1   5   5  78   8
# 2  10  11  12  13

# %% [markdown]
# READING FROM HTML INPUT

# %%
datahtml = pd.read_html('https://www.fdic.gov/bank/individual/failed/banklist.html')

#### notee that depending on the size of html,
#### jupyter will take time to read and process the data.
#### output is a list
#### this command, picks up every table element that is present in html file
#### table references markings (can be found in the html source code "view source")
### this command, creates a list of all table elements and converts each item to data frame)

# %%
type(datahtml)
# Out:
# list

# %%
len(datahtml)
# Out:
# 1

# %%
type(datahtml)
# Out:
# list

# %%
#### to check the first item in list --
### there is only onee table in the website...index 0 of list datahtml
datahtml[0]
# Out:
#                                              Bank Name                City  \
# 0                  Washington Federal Bank for Savings             Chicago
# 1      The Farmers and Merchants State Bank of Argonia             Argonia
# 2                                  Fayette County Bank          Saint Elmo
# 3    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 4                                       First NBC Bank         New Orleans
# 5                                        Proficio Bank  Cottonwood Heights
# 6                        Seaway Bank and Trust Company             Chicago
# 7                               Harvest Community Bank          Pennsville
# 8                                          Allied Bank            Mulberry
# 9                         The Woodbury Banking Company            Woodbury
# 10                              First CornerStone Bank     King of Prussia
# ...

# %%
### look at top 5 rows
datahtml[0].head()
# Out:
#                                            Bank Name         City  ST   CERT  \
# 0                Washington Federal Bank for Savings      Chicago  IL  30570
# 1    The Farmers and Merchants State Bank of Argonia      Argonia  KS  17719
# 2                                Fayette County Bank   Saint Elmo  IL   1802
# 3  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI  30003
# 4                                     First NBC Bank  New Orleans  LA  58302
#
#                  Acquiring Institution       Closing Date       Updated Date
# 0                   Royal Savings Bank  December 15, 2017  February 21, 2018
# 1                          Conway Bank   October 13, 2017  February 21, 2018
# 2            United Fidelity Bank, fsb       May 26, 2017   January 29, 2019
# 3  First-Citizens Bank & Trust Company        May 5, 2017     March 22, 2018
# 4                         Whitney Bank     April 28, 2017   January 29, 2019

# %%
### bottom 5 rows
datahtml[0].tail()
# Out:
#                              Bank Name        City  ST   CERT  \
# 550                 Superior Bank, FSB    Hinsdale  IL  32646
# 551                Malta National Bank       Malta  OH   6629
# 552    First Alliance Bank & Trust Co.  Manchester  NH  34264
# 553  National State Bank of Metropolis  Metropolis  IL   3815
# 554                   Bank of Honolulu    Honolulu  HI  21029
#
#                    Acquiring Institution       Closing Date       Updated Date
# 550                Superior Federal, FSB      July 27, 2001    August 19, 2014
# 551                    North Valley Bank        May 3, 2001  November 18, 2002
# 552  Southern New Hampshire Bank & Trust   February 2, 2001  February 18, 2003
# 553              Banterra Bank of Marion  December 14, 2000     March 17, 2005
# 554                   Bank of the Orient   October 13, 2000     March 17, 2005

# %%
### bottom 10 rows
datahtml[0].head(10)
# Out:
#                                            Bank Name                City  ST  \
# 0                Washington Federal Bank for Savings             Chicago  IL
# 1    The Farmers and Merchants State Bank of Argonia             Argonia  KS
# 2                                Fayette County Bank          Saint Elmo  IL
# 3  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 4                                     First NBC Bank         New Orleans  LA
# 5                                      Proficio Bank  Cottonwood Heights  UT
# 6                      Seaway Bank and Trust Company             Chicago  IL
# 7                             Harvest Community Bank          Pennsville  NJ
# 8                                        Allied Bank            Mulberry  AR
# 9                       The Woodbury Banking Company            Woodbury  GA
#
#     CERT                Acquiring Institution        Closing Date  \
# ...

# %%
datahtml[0].tail(10)
# Out:
#                              Bank Name           City  ST   CERT  \
# 545                       NextBank, NA        Phoenix  AZ  22314
# 546           Oakwood Deposit Bank Co.        Oakwood  OH   8966
# 547              Bank of Sierra Blanca  Sierra Blanca  TX  22002
# 548      Hamilton Bank, NA  En Espanol          Miami  FL  24382
# 549             Sinclair National Bank       Gravette  AR  34248
# 550                 Superior Bank, FSB       Hinsdale  IL  32646
# 551                Malta National Bank          Malta  OH   6629
# 552    First Alliance Bank & Trust Co.     Manchester  NH  34264
# 553  National State Bank of Metropolis     Metropolis  IL   3815
# 554                   Bank of Honolulu       Honolulu  HI  21029
#
#                    Acquiring Institution       Closing Date  \
# 545                          No Acquirer   February 7, 2002
# 546       The State Bank & Trust Company   February 1, 2002
# 547     The Security State Bank of Pecos   January 18, 2002
# ...

# %% [markdown]
# WORKING WITH SQL IN PANDAS
# PANDAS IS NOT THE BEST WAY TO READ A SQL DB
# WE WILL BUILD A VERY SIMPLE SQL ENGINE JUST TO SHOW HOW PANDAS CAN BE USED TO READ TABLES
# SPECIFIC DRIVERS NEED TO BE USED FOR SPECIFIC SQL DB LIKE POSTGRESS, MYSQL ETC

# %%
#### helps create a simple sql engine
from sqlalchemy import create_engine

# %%
### creates a small, temp sqllite engine which is in memory (local desktop Ram)
mydb = create_engine('sqlite:///:memory:')

# %%
df
# Out:
#     A   B   C   D
# 0   1   2   3   4
# 1   5   5  78   8
# 2  10  11  12  13

# %%
#### this engine is a connection. go over the help document. 
### pandas is not great with sqls. look for specialized
#### python librraries
df.to_sql('my_table1',con=mydb)

# %%
sqldf = pd.read_sql('my_table1',con=mydb)

# %%
sqldf
# Out:
#    index   A   B   C   D
# 0      0   1   2   3   4
# 1      1   5   5  78   8
# 2      2  10  11  12  13

# %%
- Matplotlib - 45 mins
- scipy - 30 mins
- webscraping - 40


- machine learning - 4 hrs
           supervised - Linear Regression, Logistic regression, KNN
                         unsupervised - PCA , Clustering
- NLP - 4
- webscraping - 45 

-hadop and spark - theory

- project - 2:5
